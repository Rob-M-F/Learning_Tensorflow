# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
stopwords = ['a', 'able', 'about', 'across', 'after', 'all', 'almost', 'also', 'am', 
             'among', 'an', 'and', 'any', 'are', 'as', 'at', 'be', 'because', 'been', 
             'but', 'by', 'can', 'cannot', 'could', 'dear', 'did', 'do', 'does', 
             'either', 'else', 'ever', 'every', 'for', 'from', 'get', 'got', 'had', 
             'has', 'have', 'he', 'her', 'hers', 'him', 'his', 'how', 'however', 'i', 
             'if', 'in', 'into', 'is', 'it', 'its', 'just', 'least', 'let', 'like', 
             'likely', 'may', 'me', 'might', 'most', 'must', 'my', 'neither', 'no', 
             'nor', 'not', 'of', 'off', 'often', 'on', 'only', 'or', 'other', 'our', 
             'own', 'rather', 'said', 'say', 'says', 'she', 'should', 'since', 'so', 
             'some', 'than', 'that', 'the', 'their', 'them', 'then', 'there', 'these', 
             'they', 'this', 'tis', 'to', 'too', 'twas', 'us', 'wants', 'was', 'we', 
             'were', 'what', 'when', 'where', 'which', 'while', 'who', 'whom', 'why', 
             'will', 'with', 'would', 'yet', 'you', 'your']

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data

rawWords = read_data(filename)
print('Data size %d' % len(rawWords))

words = []
for word in rawWords:
    if word not in stopwords:
        words.append(word)
        
print('Data size %d' % len(rawWords))
# Out:
# Data size 17005207
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 417343], ('one', 411764), ('zero', 264975), ('nine', 250430), ('two', 192644)]
# Sample data [5125, 2970, 122, 3023, 12, 17, 86, 60, 642, 387]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'term', 'abuse', 'first', 'used', 'against', 'early']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'term', 'term', 'abuse', 'abuse', 'first', 'first']
#     labels: ['anarchism', 'term', 'originated', 'abuse', 'term', 'first', 'used', 'abuse']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['term', 'term', 'term', 'term', 'abuse', 'abuse', 'abuse', 'abuse']
#     labels: ['abuse', 'anarchism', 'first', 'originated', 'first', 'term', 'used', 'originated']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 5.533501
# Nearest to several: hae, cathal, grundgesetz, ensures, parti, kantian, eigenvalues, fingerboard,
# Nearest to used: mules, distantly, caliphs, cuisines, section, attic, resignation, abdurrahman,
# Nearest to under: approximants, prevailed, heraclitus, nationalities, visited, framework, fiber, romanticized,
# Nearest to number: doctor, counterpoint, relentlessly, nu, monopolistic, hellboy, gamow, cheka,
# Nearest to two: safi, sanctions, redevelopment, pueblo, filmmaker, latch, electrical, dunwich,
# Nearest to based: clarification, vecchio, phenomenal, jameson, defer, budding, climax, cheyenne,
# Nearest to g: younger, deported, photosensitive, matilda, dw, celestial, lesser, espoused,
# Nearest to zero: stonehenge, keg, lenin, committing, samuelson, sight, unbeaten, factorials,
# Nearest to early: chamber, francophone, beavers, burkert, rgb, wickham, pane, rebuilding,
# Nearest to called: dks, woodbridge, africana, sacrum, nuclear, viciously, explained, adhesives,
# Nearest to use: fudge, kicker, kde, voter, roam, induction, allegorical, enjoyment,
# Nearest to year: started, inquisitors, sharm, tacoma, stagnation, petrograd, osamu, contingents,
# Nearest to even: distributive, tanistry, mammoth, dairy, benzyl, pater, amplifier, botany,
# Nearest to national: adored, indivisible, hawley, toppling, dispelled, dojos, edu, heretofore,
# Nearest to s: consented, arrests, hydrolysis, hereafter, electrically, schechter, beatings, mama,
# Nearest to during: rutherford, bismarck, stews, valued, invades, normalization, format, rewritten,
# Average loss at step 2000: 4.595963
# Average loss at step 4000: 4.164827
# Average loss at step 6000: 3.925592
# Average loss at step 8000: 3.948298
# Average loss at step 10000: 3.759215
# Nearest to several: hae, fingerboard, cathal, semiology, kodansha, abbeys, alford, eigenvalues,
# Nearest to used: sistine, both, section, publisher, csv, attic, mules, distantly,
# Nearest to under: heraclitus, erythrocytes, germain, spelling, precarious, prevailed, approximants, fiber,
# Nearest to number: counterpoint, doctor, numbers, relentlessly, prepare, nu, interrupting, fluctuates,
# Nearest to two: three, four, five, six, zero, eight, seven, nine,
# Nearest to based: clarification, vecchio, phenomenal, budding, decimus, diocesan, coyne, reluctance,
# Nearest to g: younger, photosensitive, elaborately, lesser, matilda, espoused, grafton, gide,
# Nearest to zero: five, nine, three, six, seven, four, eight, two,
# Nearest to early: chamber, burkert, wickham, andersonville, beavers, leukemia, rgb, almoravid,
# Nearest to called: dks, sacrum, playground, nuclear, breakbeats, yemen, vampire, explained,
# Nearest to use: complicates, absolutely, congreso, gnasher, voter, herds, many, genoese,
# Nearest to year: next, inquisitors, stagnation, tacoma, goncourt, started, thinking, apt,
# Nearest to even: distributive, god, converging, satchmo, tanistry, benzyl, apr, paradoxical,
# Nearest to national: dispelled, hsv, farnsworth, hawley, brainwashing, indivisible, dojos, galatia,
# Nearest to s: led, argonauts, kubitzki, tagalog, universes, schedules, proportionality, swimming,
# Nearest to during: indebted, repeal, tableland, deaths, war, medicaid, stews, proxima,
# Average loss at step 12000: 3.731265
# Average loss at step 14000: 3.778476
# Average loss at step 16000: 3.725224
# Average loss at step 18000: 3.765307
# Average loss at step 20000: 3.762200
# Nearest to several: many, rosary, abbeys, hae, number, begin, ordinations, nt,
# Nearest to used: use, derwent, estudios, abuse, soriano, herbivore, coalesced, simple,
# Nearest to under: fiber, spelling, heraclitus, awe, erythrocytes, precarious, secures, termini,
# Nearest to number: numbers, many, variety, counterpoint, detractors, processed, several, tfl,
# Nearest to two: three, four, five, six, seven, one, zero, eight,
# Nearest to based: clarification, phenomenal, decimus, vecchio, human, cucumbers, reluctance, coyne,
# Nearest to g: r, younger, grafton, photosensitive, f, duval, espoused, lesser,
# Nearest to zero: five, seven, six, three, four, eight, nine, two,
# Nearest to early: later, chamber, burkert, aleksandar, late, andersonville, modernism, almoravid,
# Nearest to called: explained, playground, dks, opencyc, andover, sacrum, breakbeats, pedro,
# Nearest to use: used, congreso, absolutely, complicates, effect, varsity, lynch, hashimoto,
# Nearest to year: years, day, supersymmetric, rochelle, pannonian, time, april, stagnation,
# Nearest to even: converging, benzyl, smile, blubber, surround, uu, dismantling, dairy,
# Nearest to national: galatia, romulus, hsv, international, inviscid, kruger, indivisible, farnsworth,
# Nearest to s: actively, argonauts, tells, whose, proportionality, exercised, led, antoni,
# Nearest to during: war, tableland, indebted, pierced, televised, parsing, tormented, emo,
# Average loss at step 22000: 3.753863
# Average loss at step 24000: 3.578274
# Average loss at step 26000: 3.647009
# Average loss at step 28000: 3.719099
# Average loss at step 30000: 3.709998
# Nearest to several: many, various, few, rosary, variety, begin, hae, aggressive,
# Nearest to used: use, called, derwent, soriano, mckenna, estudios, given, herbivore,
# Nearest to under: joni, nanyang, repeatable, spelling, over, romanticized, domingo, fiber,
# Nearest to number: numbers, variety, many, processed, counterpoint, mortar, humanly, several,
# Nearest to two: three, four, one, six, five, seven, eight, nine,
# Nearest to based: clarification, phenomenal, reluctance, decimus, cheyenne, savoie, dani, coyne,
# Nearest to g: r, f, younger, grafton, photosensitive, espoused, misguided, barkley,
# Nearest to zero: five, four, seven, eight, six, three, nine, two,
# Nearest to early: late, later, modernism, august, periodical, sandwiched, burkert, aleksandar,
# Nearest to called: used, known, see, referred, made, pedro, die, tunisian,
# Nearest to use: used, complicates, varsity, anisotropic, gnasher, lynch, absolutely, congreso,
# Nearest to year: years, time, utf, supersymmetric, day, rochelle, stagnation, sped,
# Nearest to even: converging, much, evoke, dismantling, interchangeable, many, uu, altitudes,
# Nearest to national: romulus, american, international, galatia, fading, inviscid, council, indivisible,
# Nearest to s: squaw, whose, octagonal, led, enclaves, sister, schedules, leo,
# Nearest to during: war, emo, quito, wade, first, parsing, time, until,
# Average loss at step 32000: 3.631410
# Average loss at step 34000: 3.665221
# Average loss at step 36000: 3.681923
# Average loss at step 38000: 3.647785
# Average loss at step 40000: 3.513335
# Nearest to several: many, number, various, including, few, rosary, variety, aggressive,
# Nearest to used: use, called, derwent, using, uses, associated, gaiman, refers,
# Nearest to under: over, joni, domingo, spelling, yorkist, rigidly, federko, heraclitus,
# Nearest to number: numbers, many, several, variety, various, size, few, nike,
# Nearest to two: three, four, five, six, one, seven, eight, zero,
# Nearest to based: reluctance, participates, cheyenne, clarification, surjective, diogenes, decimus, richland,
# Nearest to g: f, grafton, wavering, barkley, r, ammonia, n, deported,
# Nearest to zero: five, six, four, eight, nine, three, seven, two,
# Nearest to early: late, later, modernism, august, during, catamarans, november, mensa,
# Nearest to called: known, referred, used, tunisian, see, considered, stonewall, chi,
# Nearest to use: used, complicates, carrying, varsity, canonised, possible, ile, congreso,
# Nearest to year: day, years, time, utf, panentheistic, supersymmetric, month, domestication,
# Nearest to even: much, daime, still, converging, uu, evoke, dismantling, many,
# Nearest to national: council, romulus, fading, smoker, boone, galatia, zones, inviscid,
# Nearest to s: apartheid, whose, see, samoan, morphemes, mitzvot, supp, argonauts,
# Nearest to during: war, emo, time, before, over, until, early, wade,
# Average loss at step 42000: 3.458628
# Average loss at step 44000: 3.629436
# Average loss at step 46000: 3.624302
# Average loss at step 48000: 3.628444
# Average loss at step 50000: 3.469873
# Nearest to several: many, various, few, later, including, earlier, rosary, number,
# Nearest to used: use, called, referred, gaiman, designed, requires, uses, herbivore,
# Nearest to under: joni, romanticized, rigidly, over, spreading, repeatable, spelling, domingo,
# Nearest to number: numbers, variety, many, several, rta, set, size, properties,
# Nearest to two: three, six, four, five, zero, one, seven, eight,
# Nearest to based: reluctance, participates, clarification, cheyenne, tm, diogenes, surjective, inspector,
# Nearest to g: f, barkley, m, j, mancini, misguided, duval, hoffman,
# Nearest to zero: five, eight, four, six, three, seven, two, nine,
# Nearest to early: late, later, august, during, modernism, period, mensa, periodical,
# Nearest to called: referred, known, used, given, iceman, yr, pedro, soriano,
# Nearest to use: used, carrying, anisotropic, using, finding, chromatography, argue, gnasher,
# Nearest to year: years, day, supersymmetric, time, season, utf, centuries, panentheistic,
# Nearest to even: much, far, daime, still, generally, stint, clearly, become,
# Nearest to national: australian, zones, conspicuous, club, galatia, thyestes, selassie, federation,
# Nearest to s: limestone, whose, argonauts, prom, topeka, named, tallies, verus,
# Nearest to during: before, throughout, until, early, war, through, period, end,
# Average loss at step 52000: 3.585099
# Average loss at step 54000: 3.651005
# Average loss at step 56000: 3.641649
# Average loss at step 58000: 3.595205
# Average loss at step 60000: 3.576904
# Nearest to several: many, various, few, later, including, variety, both, different,
# Nearest to used: use, referred, although, uses, called, requires, using, designed,
# Nearest to under: joni, over, consternation, romanticized, appointed, rigidly, spelling, ordovician,
# Nearest to number: numbers, variety, many, several, nike, rta, size, moabite,
# Nearest to two: three, six, four, one, five, seven, zero, eight,
# Nearest to based: found, derived, produced, renaming, participates, reluctance, developed, called,
# Nearest to g: f, n, k, r, c, y, duval, b,
# Nearest to zero: eight, five, three, six, four, seven, nine, two,
# Nearest to early: late, during, august, modernism, march, later, until, beginning,
# Nearest to called: referred, known, used, given, based, muggs, iceman, soriano,
# Nearest to use: used, using, provide, uses, scientifically, correct, practice, anisotropic,
# Nearest to year: years, day, time, month, supersymmetric, centuries, nol, months,
# Nearest to even: much, still, characterized, generally, far, distraction, daime, being,
# Nearest to national: galatia, labour, public, australian, legislature, zones, unction, inviscid,
# Nearest to s: whose, ballard, transportation, falcons, jeans, joined, attract, topeka,
# Nearest to during: early, before, war, end, until, throughout, through, late,
# Average loss at step 62000: 3.494550
# Average loss at step 64000: 3.449064
# Average loss at step 66000: 3.546502
# Average loss at step 68000: 3.509451
# Average loss at step 70000: 3.583491
# Nearest to several: many, various, few, numerous, including, number, later, earlier,
# Nearest to used: use, referred, uses, refers, given, using, applied, developed,
# Nearest to under: over, mckernan, appointed, consternation, rigidly, navigational, injustices, romanticized,
# Nearest to number: numbers, many, variety, several, various, nike, amounts, size,
# Nearest to two: three, five, four, six, seven, one, eight, zero,
# Nearest to based: including, derived, include, participates, understanding, lists, surjective, found,
# Nearest to g: f, c, r, j, mu, k, barkley, h,
# Nearest to zero: five, seven, four, eight, six, three, two, nine,
# Nearest to early: late, during, later, period, march, august, modernism, earliest,
# Nearest to called: referred, known, found, defined, whose, named, see, derived,
# Nearest to use: used, using, uses, provide, carrying, sami, usage, provost,
# Nearest to year: years, months, month, day, nol, time, eroding, season,
# Nearest to even: much, still, generally, uu, daime, distraction, although, amen,
# Nearest to national: galatia, australian, polytechnic, legislature, unction, inviscid, suda, american,
# Nearest to s: topeka, whose, kwakiutl, socony, profoundly, sears, belly, spear,
# Nearest to during: throughout, before, through, until, early, end, period, war,
# Average loss at step 72000: 3.385858
# Average loss at step 74000: 3.523641
# Average loss at step 76000: 3.540070
# Average loss at step 78000: 3.529905
# Average loss at step 80000: 3.491651
# Nearest to several: many, various, few, numerous, number, variety, such, different,
# Nearest to used: referred, use, uses, known, called, although, developed, refers,
# Nearest to under: electrochemical, mckernan, over, rigidly, deflected, navigational, injustices, joni,
# Nearest to number: numbers, variety, several, many, size, nike, various, amount,
# Nearest to two: four, three, five, one, six, seven, eight, isbn,
# Nearest to based: surjective, participates, derived, tm, s, clarification, called, include,
# Nearest to g: e, echoed, faber, buber, c, latch, kanu, f,
# Nearest to zero: five, three, four, seven, eight, six, nine, two,
# Nearest to early: late, later, august, during, march, mid, earlier, throughout,
# Nearest to called: referred, known, named, used, iceman, given, mckenna, described,
# Nearest to use: used, using, uses, provost, provide, usage, congreso, stowe,
# Nearest to year: month, years, day, time, months, nol, utf, twenty,
# Nearest to even: much, still, generally, considerably, uu, always, others, although,
# Nearest to national: australian, legislature, international, unction, american, galatia, agency, sputnik,
# Nearest to s: whose, made, wrote, based, gives, verus, anemometers, entered,
# Nearest to during: throughout, period, until, before, early, war, through, end,
# Average loss at step 82000: 3.339191
# Average loss at step 84000: 3.495190
# Average loss at step 86000: 3.348874
# Average loss at step 88000: 3.329516
# Average loss at step 90000: 3.550348
# Nearest to several: many, various, few, numerous, number, those, both, different,
# Nearest to used: use, referred, uses, using, appear, refers, seen, associated,
# Nearest to under: over, electrochemical, spelling, deflected, financing, leaky, navigational, granted,
# Nearest to number: numbers, several, variety, many, various, size, both, length,
# Nearest to two: three, four, five, six, seven, one, eight, zero,
# Nearest to based: developed, found, called, although, include, whose, publishes, tm,
# Nearest to g: h, f, r, k, latch, p, barkley, faber,
# Nearest to zero: five, six, eight, nine, seven, four, three, two,
# Nearest to early: late, earlier, mid, earliest, later, beginning, apprenticeship, august,
# Nearest to called: referred, known, considered, based, described, found, iceman, intension,
# Nearest to use: used, using, usage, uses, provide, clerics, correct, carte,
# Nearest to year: years, month, months, time, season, day, days, nol,
# Nearest to even: much, generally, considerably, detergent, never, still, others, daime,
# Nearest to national: international, polytechnic, australian, smoker, unction, agency, meshech, galatia,
# Nearest to s: whose, wrote, led, gave, refuges, according, based, named,
# Nearest to during: throughout, until, before, late, period, led, result, end,
# Average loss at step 92000: 3.444030
# Average loss at step 94000: 3.275793
# Average loss at step 96000: 3.504774
# Average loss at step 98000: 3.523231
# Average loss at step 100000: 3.520727
# Nearest to several: many, few, numerous, various, number, those, both, including,
# Nearest to used: use, referred, uses, using, called, applied, designed, refers,
# Nearest to under: electrochemical, over, flagpole, together, cambrian, navigational, exposing, deflected,
# Nearest to number: numbers, several, many, variety, various, few, amount, majority,
# Nearest to two: four, five, three, six, seven, eight, one, zero,
# Nearest to based: developed, publishes, include, tm, eschatological, whose, pcs, classic,
# Nearest to g: f, duval, group, associative, kerberos, isomorphic, groups, frey,
# Nearest to zero: five, six, seven, four, three, eight, two, nine,
# Nearest to early: late, earliest, march, later, beginning, mid, throughout, earlier,
# Nearest to called: referred, known, found, iceman, described, used, considered, associated,
# Nearest to use: used, usage, using, uses, practice, congreso, lala, allocated,
# Nearest to year: month, years, day, months, season, time, utf, decade,
# Nearest to even: much, far, generally, considerably, slightly, need, still, clearly,
# Nearest to national: polytechnic, international, australian, royal, sputnik, amhara, maecenas, local,
# Nearest to s: whose, named, told, topeka, alanine, escalation, pal, limestone,
# Nearest to during: throughout, until, end, late, over, war, before, period,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
